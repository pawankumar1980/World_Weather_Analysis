# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
import pandas as pd
import numpy as np
import random
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low = -90.000,high = 90.000, size = 2000)
lngs = np.random.uniform(low = -180.000,high = 180.000, size = 2000)


# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities =[]

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count

len(cities)
# Out:
# 736

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2735ce4793cbab4e6d1f4a29bb04481d'

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through city Lists 
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 
    if (i % 50 == 0 and i >= 50):
        set_count += 1 
        record_count = 1 
    
    # Create URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log URL, set, and record numbers for each city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1

# Make an API request for each city 
    try:
       
        # Parse the JSON data
        city_weather = requests.get(city_url).json()
        
        
        # Compile needed data
        city_city = city.title()
        city_country = city_weather['sys']['country']
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_hum = city_weather['main']['humidity']
        city_cloud = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_desc = city_weather['weather'][0]['description']

        # Fill City Data list 
        city_data.append({"City": city_city,
                         "Country": city_country,
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_hum,
                         "Cloudiness": city_cloud,
                         "Wind Speed": city_wind, 
                         "Current Description": city_desc})
        
    #If an error occurs
    except: 
        print("City not found. Skipping")
        pass

    # Complete Data Retrieval    
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | vaitupu
# City not found. Skipping
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | kutum
# Processing Record 5 of Set 1 | hobart
# Processing Record 6 of Set 1 | nahrin
# Processing Record 7 of Set 1 | qaanaaq
# Processing Record 8 of Set 1 | lompoc
# Processing Record 9 of Set 1 | mys shmidta
# City not found. Skipping
# Processing Record 10 of Set 1 | avarua
# Processing Record 11 of Set 1 | severo-kurilsk
# Processing Record 12 of Set 1 | toda raisingh
# Processing Record 13 of Set 1 | mana
# Processing Record 14 of Set 1 | shenjiamen
# Processing Record 15 of Set 1 | sisimiut
# Processing Record 16 of Set 1 | bethel
# Processing Record 17 of Set 1 | rikitea
# Processing Record 18 of Set 1 | atuona
# Processing Record 19 of Set 1 | butaritari
# Processing Record 20 of Set 1 | lebu
# Processing Record 21 of Set 1 | solnechnyy
# Processing Record 22 of Set 1 | nabire
# Processing Record 23 of Set 1 | casino
# Processing Record 24 of Set 1 | puerto ayora
# Processing Record 25 of Set 1 | puerto escondido
# Processing Record 26 of Set 1 | clyde river
# Processing Record 27 of Set 1 | provideniya
# Processing Record 28 of Set 1 | kavaratti
# Processing Record 29 of Set 1 | necochea
# Processing Record 30 of Set 1 | westerly
# Processing Record 31 of Set 1 | nikolskoye
# Processing Record 32 of Set 1 | berlevag
# Processing Record 33 of Set 1 | busselton
# Processing Record 34 of Set 1 | fairbanks
# Processing Record 35 of Set 1 | mar del plata
# Processing Record 36 of Set 1 | novouzensk
# Processing Record 37 of Set 1 | terrasini
# Processing Record 38 of Set 1 | khatanga
# Processing Record 39 of Set 1 | sao filipe
# Processing Record 40 of Set 1 | kaitangata
# Processing Record 41 of Set 1 | abu samrah
# Processing Record 42 of Set 1 | los llanos de aridane
# Processing Record 43 of Set 1 | pevek
# Processing Record 44 of Set 1 | kapaa
# Processing Record 45 of Set 1 | souillac
# Processing Record 46 of Set 1 | aleksandrov gay
# Processing Record 47 of Set 1 | upernavik
# Processing Record 48 of Set 1 | puno
# Processing Record 49 of Set 1 | belushya guba
# City not found. Skipping
# Processing Record 50 of Set 1 | padang
# Processing Record 1 of Set 2 | tucuman
# Processing Record 2 of Set 2 | jamestown
# Processing Record 3 of Set 2 | sorvag
# City not found. Skipping
# Processing Record 4 of Set 2 | itarema
# Processing Record 5 of Set 2 | manicore
# Processing Record 6 of Set 2 | bonavista
# Processing Record 7 of Set 2 | port alfred
# Processing Record 8 of Set 2 | muchkapskiy
# Processing Record 9 of Set 2 | ancud
# Processing Record 10 of Set 2 | albany
# Processing Record 11 of Set 2 | kuche
# City not found. Skipping
# Processing Record 12 of Set 2 | barra do garcas
# Processing Record 13 of Set 2 | vaini
# Processing Record 14 of Set 2 | hermanus
# Processing Record 15 of Set 2 | lar
# Processing Record 16 of Set 2 | ponta do sol
# Processing Record 17 of Set 2 | samarai
# Processing Record 18 of Set 2 | bathsheba
# Processing Record 19 of Set 2 | zhigansk
# Processing Record 20 of Set 2 | mandan
# Processing Record 21 of Set 2 | burns lake
# Processing Record 22 of Set 2 | port hedland
# Processing Record 23 of Set 2 | ponta delgada
# Processing Record 24 of Set 2 | tuktoyaktuk
# Processing Record 25 of Set 2 | sur
# Processing Record 26 of Set 2 | new norfolk
# Processing Record 27 of Set 2 | akyab
# Processing Record 28 of Set 2 | barentsburg
# City not found. Skipping
# Processing Record 29 of Set 2 | winder
# Processing Record 30 of Set 2 | kruisfontein
# Processing Record 31 of Set 2 | thanh hoa
# Processing Record 32 of Set 2 | punta arenas
# Processing Record 33 of Set 2 | tuatapere
# Processing Record 34 of Set 2 | alofi
# Processing Record 35 of Set 2 | shangzhi
# Processing Record 36 of Set 2 | nizhneyansk
# City not found. Skipping
# Processing Record 37 of Set 2 | narsaq
# Processing Record 38 of Set 2 | hasaki
# Processing Record 39 of Set 2 | momostenango
# Processing Record 40 of Set 2 | bluff
# Processing Record 41 of Set 2 | selikhino
# Processing Record 42 of Set 2 | ryotsu
# Processing Record 43 of Set 2 | presidencia roque saenz pena
# Processing Record 44 of Set 2 | amderma
# City not found. Skipping
# Processing Record 45 of Set 2 | ishigaki
# Processing Record 46 of Set 2 | kaeo
# Processing Record 47 of Set 2 | bontang
# Processing Record 48 of Set 2 | kaya
# Processing Record 49 of Set 2 | arraial do cabo
# Processing Record 50 of Set 2 | leningradskiy
# Processing Record 1 of Set 3 | longyearbyen
# Processing Record 2 of Set 3 | talnakh
# Processing Record 3 of Set 3 | mahebourg
# Processing Record 4 of Set 3 | jati
# Processing Record 5 of Set 3 | taolanaro
# City not found. Skipping
# Processing Record 6 of Set 3 | khed
# Processing Record 7 of Set 3 | inhambane
# Processing Record 8 of Set 3 | grindavik
# Processing Record 9 of Set 3 | camopi
# Processing Record 10 of Set 3 | salalah
# Processing Record 11 of Set 3 | dunedin
# Processing Record 12 of Set 3 | huarmey
# Processing Record 13 of Set 3 | iqaluit
# Processing Record 14 of Set 3 | marcona
# City not found. Skipping
# Processing Record 15 of Set 3 | oyama
# Processing Record 16 of Set 3 | havoysund
# Processing Record 17 of Set 3 | tilichiki
# Processing Record 18 of Set 3 | bengkulu
# Processing Record 19 of Set 3 | cape town
# Processing Record 20 of Set 3 | cidreira
# Processing Record 21 of Set 3 | hofn
# Processing Record 22 of Set 3 | dwarka
# Processing Record 23 of Set 3 | belaya gora
# Processing Record 24 of Set 3 | san vicente
# Processing Record 25 of Set 3 | visnes
# Processing Record 26 of Set 3 | east london
# Processing Record 27 of Set 3 | adrar
# Processing Record 28 of Set 3 | baljevac
# Processing Record 29 of Set 3 | zyryanka
# Processing Record 30 of Set 3 | cabedelo
# Processing Record 31 of Set 3 | guajara-mirim
# City not found. Skipping
# Processing Record 32 of Set 3 | bakchar
# Processing Record 33 of Set 3 | kampot
# Processing Record 34 of Set 3 | georgetown
# Processing Record 35 of Set 3 | bunia
# Processing Record 36 of Set 3 | rocha
# Processing Record 37 of Set 3 | zeya
# Processing Record 38 of Set 3 | shepetivka
# Processing Record 39 of Set 3 | chuy
# Processing Record 40 of Set 3 | barrow
# Processing Record 41 of Set 3 | kieta
# Processing Record 42 of Set 3 | noumea
# Processing Record 43 of Set 3 | pangnirtung
# Processing Record 44 of Set 3 | marawi
# Processing Record 45 of Set 3 | haines junction
# Processing Record 46 of Set 3 | gravelbourg
# Processing Record 47 of Set 3 | castro
# Processing Record 48 of Set 3 | chokurdakh
# Processing Record 49 of Set 3 | airai
# Processing Record 50 of Set 3 | mogadishu
# Processing Record 1 of Set 4 | mahajanga
# Processing Record 2 of Set 4 | north bend
# Processing Record 3 of Set 4 | saleaula
# City not found. Skipping
# Processing Record 4 of Set 4 | illoqqortoormiut
# City not found. Skipping
# Processing Record 5 of Set 4 | olafsvik
# Processing Record 6 of Set 4 | mugur-aksy
# Processing Record 7 of Set 4 | codrington
# Processing Record 8 of Set 4 | vysokogornyy
# Processing Record 9 of Set 4 | kolindros
# Processing Record 10 of Set 4 | srivardhan
# Processing Record 11 of Set 4 | yellowknife
# Processing Record 12 of Set 4 | port blair
# Processing Record 13 of Set 4 | makakilo city
# Processing Record 14 of Set 4 | kizu
# City not found. Skipping
# Processing Record 15 of Set 4 | taoudenni
# Processing Record 16 of Set 4 | rawson
# Processing Record 17 of Set 4 | saint anthony
# Processing Record 18 of Set 4 | lafia
# Processing Record 19 of Set 4 | viedma
# Processing Record 20 of Set 4 | sobolevo
# Processing Record 21 of Set 4 | hithadhoo
# Processing Record 22 of Set 4 | cockburn town
# Processing Record 23 of Set 4 | mahadday weyne
# City not found. Skipping
# Processing Record 24 of Set 4 | saint-philippe
# Processing Record 25 of Set 4 | kahului
# Processing Record 26 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 27 of Set 4 | ixtapa
# Processing Record 28 of Set 4 | kodiak
# Processing Record 29 of Set 4 | guatire
# Processing Record 30 of Set 4 | barawe
# City not found. Skipping
# Processing Record 31 of Set 4 | tsihombe
# City not found. Skipping
# Processing Record 32 of Set 4 | areni
# Processing Record 33 of Set 4 | gizo
# Processing Record 34 of Set 4 | daoukro
# Processing Record 35 of Set 4 | hilo
# Processing Record 36 of Set 4 | taltal
# Processing Record 37 of Set 4 | quatre cocos
# Processing Record 38 of Set 4 | shubarshi
# Processing Record 39 of Set 4 | labuhan
# Processing Record 40 of Set 4 | kidal
# Processing Record 41 of Set 4 | muros
# Processing Record 42 of Set 4 | ribeira grande
# Processing Record 43 of Set 4 | berbera
# Processing Record 44 of Set 4 | guardiagrele
# Processing Record 45 of Set 4 | helena
# Processing Record 46 of Set 4 | bredasdorp
# Processing Record 47 of Set 4 | dondo
# Processing Record 48 of Set 4 | skjervoy
# Processing Record 49 of Set 4 | karkaralinsk
# City not found. Skipping
# Processing Record 50 of Set 4 | victoria
# Processing Record 1 of Set 5 | geraldton
# Processing Record 2 of Set 5 | tiksi
# Processing Record 3 of Set 5 | ouesso
# Processing Record 4 of Set 5 | caracollo
# Processing Record 5 of Set 5 | ibra
# Processing Record 6 of Set 5 | araouane
# Processing Record 7 of Set 5 | port hardy
# Processing Record 8 of Set 5 | caravelas
# Processing Record 9 of Set 5 | coquimbo
# Processing Record 10 of Set 5 | gat
# Processing Record 11 of Set 5 | hanstholm
# Processing Record 12 of Set 5 | saskylakh
# Processing Record 13 of Set 5 | putina
# Processing Record 14 of Set 5 | taburi
# City not found. Skipping
# Processing Record 15 of Set 5 | kefalos
# Processing Record 16 of Set 5 | yanam
# Processing Record 17 of Set 5 | fortuna
# Processing Record 18 of Set 5 | micheweni
# Processing Record 19 of Set 5 | villazon
# Processing Record 20 of Set 5 | vardo
# Processing Record 21 of Set 5 | altamira
# Processing Record 22 of Set 5 | leh
# Processing Record 23 of Set 5 | tagusao
# Processing Record 24 of Set 5 | northam
# Processing Record 25 of Set 5 | boguchany
# Processing Record 26 of Set 5 | ginir
# Processing Record 27 of Set 5 | middle island
# Processing Record 28 of Set 5 | port elizabeth
# Processing Record 29 of Set 5 | walvis bay
# Processing Record 30 of Set 5 | vila
# Processing Record 31 of Set 5 | lydenburg
# Processing Record 32 of Set 5 | lagoa
# Processing Record 33 of Set 5 | korla
# Processing Record 34 of Set 5 | athabasca
# Processing Record 35 of Set 5 | mount gambier
# Processing Record 36 of Set 5 | buchanan
# Processing Record 37 of Set 5 | nanortalik
# Processing Record 38 of Set 5 | puerto baquerizo moreno
# Processing Record 39 of Set 5 | jardim
# Processing Record 40 of Set 5 | horodnytsya
# Processing Record 41 of Set 5 | baoning
# Processing Record 42 of Set 5 | namibe
# Processing Record 43 of Set 5 | mount isa
# Processing Record 44 of Set 5 | constitucion
# Processing Record 45 of Set 5 | houma
# Processing Record 46 of Set 5 | faridnagar
# Processing Record 47 of Set 5 | muzhi
# Processing Record 48 of Set 5 | bara
# Processing Record 49 of Set 5 | nioro
# Processing Record 50 of Set 5 | worland
# Processing Record 1 of Set 6 | umzimvubu
# City not found. Skipping
# Processing Record 2 of Set 6 | alice springs
# Processing Record 3 of Set 6 | dubrovytsya
# Processing Record 4 of Set 6 | lloydminster
# Processing Record 5 of Set 6 | ye
# City not found. Skipping
# Processing Record 6 of Set 6 | isangel
# Processing Record 7 of Set 6 | woodland
# Processing Record 8 of Set 6 | port lincoln
# Processing Record 9 of Set 6 | paamiut
# Processing Record 10 of Set 6 | manuk mangkaw
# Processing Record 11 of Set 6 | tumannyy
# City not found. Skipping
# Processing Record 12 of Set 6 | muravlenko
# Processing Record 13 of Set 6 | nouadhibou
# Processing Record 14 of Set 6 | karpogory
# Processing Record 15 of Set 6 | broken hill
# Processing Record 16 of Set 6 | roebourne
# Processing Record 17 of Set 6 | mwene-ditu
# Processing Record 18 of Set 6 | namtsy
# Processing Record 19 of Set 6 | norman wells
# Processing Record 20 of Set 6 | maragogi
# Processing Record 21 of Set 6 | carnarvon
# Processing Record 22 of Set 6 | seoul
# Processing Record 23 of Set 6 | skalistyy
# City not found. Skipping
# Processing Record 24 of Set 6 | namatanai
# Processing Record 25 of Set 6 | katsuura
# Processing Record 26 of Set 6 | trapani
# Processing Record 27 of Set 6 | cabo san lucas
# Processing Record 28 of Set 6 | grand centre
# City not found. Skipping
# Processing Record 29 of Set 6 | buhe
# Processing Record 30 of Set 6 | nelson bay
# Processing Record 31 of Set 6 | palabuhanratu
# City not found. Skipping
# Processing Record 32 of Set 6 | kulhudhuffushi
# Processing Record 33 of Set 6 | havre-saint-pierre
# Processing Record 34 of Set 6 | bizhbulyak
# Processing Record 35 of Set 6 | fort nelson
# Processing Record 36 of Set 6 | southbridge
# Processing Record 37 of Set 6 | babu
# Processing Record 38 of Set 6 | bosaso
# Processing Record 39 of Set 6 | tura
# Processing Record 40 of Set 6 | eydhafushi
# Processing Record 41 of Set 6 | druzhba
# Processing Record 42 of Set 6 | asau
# Processing Record 43 of Set 6 | ostrovnoy
# Processing Record 44 of Set 6 | dindori
# Processing Record 45 of Set 6 | torbay
# Processing Record 46 of Set 6 | cayenne
# Processing Record 47 of Set 6 | omboue
# Processing Record 48 of Set 6 | ahipara
# Processing Record 49 of Set 6 | togur
# Processing Record 50 of Set 6 | boende
# Processing Record 1 of Set 7 | neiafu
# Processing Record 2 of Set 7 | coihaique
# Processing Record 3 of Set 7 | trincomalee
# Processing Record 4 of Set 7 | vila franca do campo
# Processing Record 5 of Set 7 | natuba
# Processing Record 6 of Set 7 | sept-iles
# Processing Record 7 of Set 7 | thompson
# Processing Record 8 of Set 7 | hamilton
# Processing Record 9 of Set 7 | faanui
# Processing Record 10 of Set 7 | atar
# Processing Record 11 of Set 7 | bayji
# Processing Record 12 of Set 7 | senanga
# Processing Record 13 of Set 7 | merauke
# Processing Record 14 of Set 7 | kaseda
# Processing Record 15 of Set 7 | leshukonskoye
# Processing Record 16 of Set 7 | sabang
# Processing Record 17 of Set 7 | tasiilaq
# Processing Record 18 of Set 7 | guerrero negro
# Processing Record 19 of Set 7 | mutoko
# Processing Record 20 of Set 7 | villamontes
# Processing Record 21 of Set 7 | saint george
# Processing Record 22 of Set 7 | mto wa mbu
# Processing Record 23 of Set 7 | waipawa
# Processing Record 24 of Set 7 | hervey bay
# Processing Record 25 of Set 7 | maxixe
# Processing Record 26 of Set 7 | salinopolis
# Processing Record 27 of Set 7 | touros
# Processing Record 28 of Set 7 | maloy
# Processing Record 29 of Set 7 | maceio
# Processing Record 30 of Set 7 | chapais
# Processing Record 31 of Set 7 | forio
# Processing Record 32 of Set 7 | bilibino
# Processing Record 33 of Set 7 | byadgi
# Processing Record 34 of Set 7 | tommot
# Processing Record 35 of Set 7 | bandarbeyla
# Processing Record 36 of Set 7 | puerto carreno
# Processing Record 37 of Set 7 | kirakira
# Processing Record 38 of Set 7 | bolungarvik
# City not found. Skipping
# Processing Record 39 of Set 7 | ngukurr
# City not found. Skipping
# Processing Record 40 of Set 7 | sopelana
# Processing Record 41 of Set 7 | tunxi
# City not found. Skipping
# Processing Record 42 of Set 7 | ulaangom
# Processing Record 43 of Set 7 | ati
# Processing Record 44 of Set 7 | la uribe
# City not found. Skipping
# Processing Record 45 of Set 7 | cherskiy
# Processing Record 46 of Set 7 | margate
# Processing Record 47 of Set 7 | khorinsk
# Processing Record 48 of Set 7 | vao
# Processing Record 49 of Set 7 | charters towers
# Processing Record 50 of Set 7 | killybegs
# Processing Record 1 of Set 8 | sola
# Processing Record 2 of Set 8 | gazojak
# Processing Record 3 of Set 8 | xicotencatl
# Processing Record 4 of Set 8 | hagi
# Processing Record 5 of Set 8 | avera
# Processing Record 6 of Set 8 | nang rong
# Processing Record 7 of Set 8 | sorong
# Processing Record 8 of Set 8 | tete
# Processing Record 9 of Set 8 | pacific grove
# Processing Record 10 of Set 8 | shetpe
# Processing Record 11 of Set 8 | benghazi
# Processing Record 12 of Set 8 | burdur
# Processing Record 13 of Set 8 | monteagudo
# Processing Record 14 of Set 8 | lichinga
# Processing Record 15 of Set 8 | bolshaya glushitsa
# Processing Record 16 of Set 8 | pereslavl-zalesskiy
# Processing Record 17 of Set 8 | dikson
# Processing Record 18 of Set 8 | ziarat
# Processing Record 19 of Set 8 | setermoen
# Processing Record 20 of Set 8 | lerwick
# Processing Record 21 of Set 8 | kismayo
# Processing Record 22 of Set 8 | biskamzha
# Processing Record 23 of Set 8 | kropotkin
# Processing Record 24 of Set 8 | kargopol
# Processing Record 25 of Set 8 | aripuana
# Processing Record 26 of Set 8 | wang saphung
# Processing Record 27 of Set 8 | gushikawa
# Processing Record 28 of Set 8 | pacifica
# Processing Record 29 of Set 8 | palmas bellas
# Processing Record 30 of Set 8 | bambous virieux
# Processing Record 31 of Set 8 | anta
# Processing Record 32 of Set 8 | aksu
# Processing Record 33 of Set 8 | kampong cham
# Processing Record 34 of Set 8 | harer
# Processing Record 35 of Set 8 | vestmannaeyjar
# Processing Record 36 of Set 8 | san jose del guaviare
# Processing Record 37 of Set 8 | usinsk
# Processing Record 38 of Set 8 | qaqortoq
# Processing Record 39 of Set 8 | okhotsk
# Processing Record 40 of Set 8 | galle
# Processing Record 41 of Set 8 | san patricio
# Processing Record 42 of Set 8 | kerema
# Processing Record 43 of Set 8 | arona
# Processing Record 44 of Set 8 | novominskaya
# Processing Record 45 of Set 8 | sioux falls
# Processing Record 46 of Set 8 | tessalit
# Processing Record 47 of Set 8 | chinna salem
# Processing Record 48 of Set 8 | andenes
# Processing Record 49 of Set 8 | tautira
# Processing Record 50 of Set 8 | sao joao da barra
# Processing Record 1 of Set 9 | the valley
# Processing Record 2 of Set 9 | cam ranh
# Processing Record 3 of Set 9 | aktau
# Processing Record 4 of Set 9 | emerald
# Processing Record 5 of Set 9 | griffith
# Processing Record 6 of Set 9 | yar-sale
# Processing Record 7 of Set 9 | lorengau
# Processing Record 8 of Set 9 | troitskoye
# Processing Record 9 of Set 9 | newport
# Processing Record 10 of Set 9 | khandbari
# Processing Record 11 of Set 9 | ariquemes
# Processing Record 12 of Set 9 | porto novo
# Processing Record 13 of Set 9 | imbituba
# Processing Record 14 of Set 9 | comodoro rivadavia
# Processing Record 15 of Set 9 | anandnagar
# Processing Record 16 of Set 9 | maarianhamina
# Processing Record 17 of Set 9 | sorland
# Processing Record 18 of Set 9 | kavieng
# Processing Record 19 of Set 9 | pechenga
# Processing Record 20 of Set 9 | shuyskoye
# Processing Record 21 of Set 9 | fushun
# Processing Record 22 of Set 9 | manokwari
# Processing Record 23 of Set 9 | samusu
# City not found. Skipping
# Processing Record 24 of Set 9 | anantapur
# Processing Record 25 of Set 9 | huajuapan
# City not found. Skipping
# Processing Record 26 of Set 9 | ambilobe
# Processing Record 27 of Set 9 | wajima
# Processing Record 28 of Set 9 | kapiri mposhi
# Processing Record 29 of Set 9 | lamu
# Processing Record 30 of Set 9 | vrangel
# Processing Record 31 of Set 9 | le port
# Processing Record 32 of Set 9 | prince george
# Processing Record 33 of Set 9 | saint-pierre
# Processing Record 34 of Set 9 | kokopo
# Processing Record 35 of Set 9 | vostok
# Processing Record 36 of Set 9 | westport
# Processing Record 37 of Set 9 | khandyga
# Processing Record 38 of Set 9 | meyungs
# City not found. Skipping
# Processing Record 39 of Set 9 | itaituba
# Processing Record 40 of Set 9 | ikornnes
# Processing Record 41 of Set 9 | doctor pedro p. pena
# City not found. Skipping
# Processing Record 42 of Set 9 | kysyl-syr
# Processing Record 43 of Set 9 | deputatskiy
# Processing Record 44 of Set 9 | yarmouth
# Processing Record 45 of Set 9 | plouzane
# Processing Record 46 of Set 9 | la romana
# Processing Record 47 of Set 9 | bristol
# Processing Record 48 of Set 9 | samana
# Processing Record 49 of Set 9 | rovaniemi
# Processing Record 50 of Set 9 | wawa
# Processing Record 1 of Set 10 | alpena
# Processing Record 2 of Set 10 | feijo
# Processing Record 3 of Set 10 | sinnamary
# Processing Record 4 of Set 10 | riobamba
# Processing Record 5 of Set 10 | hambantota
# Processing Record 6 of Set 10 | hovd
# Processing Record 7 of Set 10 | waddan
# Processing Record 8 of Set 10 | gravdal
# Processing Record 9 of Set 10 | portland
# Processing Record 10 of Set 10 | huntington
# Processing Record 11 of Set 10 | ville-marie
# Processing Record 12 of Set 10 | kamenka
# Processing Record 13 of Set 10 | gambela
# Processing Record 14 of Set 10 | banmo
# City not found. Skipping
# Processing Record 15 of Set 10 | camacha
# Processing Record 16 of Set 10 | san quintin
# Processing Record 17 of Set 10 | biak
# Processing Record 18 of Set 10 | blackwater
# Processing Record 19 of Set 10 | bahar
# Processing Record 20 of Set 10 | spearfish
# Processing Record 21 of Set 10 | kamenskoye
# City not found. Skipping
# Processing Record 22 of Set 10 | young
# Processing Record 23 of Set 10 | esperance
# Processing Record 24 of Set 10 | yulara
# Processing Record 25 of Set 10 | burica
# City not found. Skipping
# Processing Record 26 of Set 10 | floro
# Processing Record 27 of Set 10 | apache junction
# Processing Record 28 of Set 10 | san cristobal
# Processing Record 29 of Set 10 | kislyakovskaya
# Processing Record 30 of Set 10 | karaul
# City not found. Skipping
# Processing Record 31 of Set 10 | kjopsvik
# Processing Record 32 of Set 10 | la palma
# Processing Record 33 of Set 10 | dondaicha
# Processing Record 34 of Set 10 | bereda
# Processing Record 35 of Set 10 | fez
# Processing Record 36 of Set 10 | godda
# Processing Record 37 of Set 10 | ucluelet
# Processing Record 38 of Set 10 | port-gentil
# Processing Record 39 of Set 10 | vadso
# Processing Record 40 of Set 10 | miri
# Processing Record 41 of Set 10 | scarborough
# Processing Record 42 of Set 10 | fort saint john
# City not found. Skipping
# Processing Record 43 of Set 10 | hami
# Processing Record 44 of Set 10 | solton
# Processing Record 45 of Set 10 | saint-louis
# Processing Record 46 of Set 10 | ugoofaaru
# Processing Record 47 of Set 10 | kaduy
# Processing Record 48 of Set 10 | semme
# Processing Record 49 of Set 10 | naze
# Processing Record 50 of Set 10 | dedovichi
# Processing Record 1 of Set 11 | attawapiskat
# City not found. Skipping
# Processing Record 2 of Set 11 | deh rawud
# City not found. Skipping
# Processing Record 3 of Set 11 | awbari
# Processing Record 4 of Set 11 | lake city
# Processing Record 5 of Set 11 | wasilla
# Processing Record 6 of Set 11 | tarko-sale
# Processing Record 7 of Set 11 | najran
# Processing Record 8 of Set 11 | antalaha
# Processing Record 9 of Set 11 | zheleznodorozhnyy
# Processing Record 10 of Set 11 | mongo
# Processing Record 11 of Set 11 | tarauaca
# Processing Record 12 of Set 11 | mmathubudukwane
# Processing Record 13 of Set 11 | oranjestad
# Processing Record 14 of Set 11 | pop
# Processing Record 15 of Set 11 | sentyabrskiy
# City not found. Skipping
# Processing Record 16 of Set 11 | mandalgovi
# Processing Record 17 of Set 11 | sedan
# Processing Record 18 of Set 11 | prince rupert
# Processing Record 19 of Set 11 | benjamin hill
# Processing Record 20 of Set 11 | sun city
# Processing Record 21 of Set 11 | jiuquan
# Processing Record 22 of Set 11 | monze
# Processing Record 23 of Set 11 | saldanha
# Processing Record 24 of Set 11 | henties bay
# Processing Record 25 of Set 11 | san policarpo
# Processing Record 26 of Set 11 | lengshuitan
# Processing Record 27 of Set 11 | trairi
# Processing Record 28 of Set 11 | sydney
# Processing Record 29 of Set 11 | antofagasta
# Processing Record 30 of Set 11 | bouloupari
# Processing Record 31 of Set 11 | verkhnevilyuysk
# Processing Record 32 of Set 11 | kytmanovo
# Processing Record 33 of Set 11 | bakel
# Processing Record 34 of Set 11 | san juan
# Processing Record 35 of Set 11 | muisne
# Processing Record 36 of Set 11 | garowe
# Processing Record 37 of Set 11 | guiong
# Processing Record 38 of Set 11 | san pedro
# Processing Record 39 of Set 11 | egvekinot
# Processing Record 40 of Set 11 | katobu
# Processing Record 41 of Set 11 | garden city
# Processing Record 42 of Set 11 | mnogovershinnyy
# Processing Record 43 of Set 11 | denpasar
# Processing Record 44 of Set 11 | dingle
# Processing Record 45 of Set 11 | bargal
# City not found. Skipping
# Processing Record 46 of Set 11 | ilulissat
# Processing Record 47 of Set 11 | mitu
# Processing Record 48 of Set 11 | halalo
# City not found. Skipping
# Processing Record 49 of Set 11 | ballina
# Processing Record 50 of Set 11 | flinders
# Processing Record 1 of Set 12 | rockland
# Processing Record 2 of Set 12 | turbat
# Processing Record 3 of Set 12 | quelimane
# Processing Record 4 of Set 12 | lavrentiya
# Processing Record 5 of Set 12 | gamba
# Processing Record 6 of Set 12 | vila velha
# Processing Record 7 of Set 12 | tamayo
# Processing Record 8 of Set 12 | champerico
# Processing Record 9 of Set 12 | oistins
# Processing Record 10 of Set 12 | masvingo
# Processing Record 11 of Set 12 | strathpeffer
# Processing Record 12 of Set 12 | yeniseysk
# Processing Record 13 of Set 12 | mogoytuy
# Processing Record 14 of Set 12 | zaplyusye
# City not found. Skipping
# Processing Record 15 of Set 12 | kodinsk
# Processing Record 16 of Set 12 | seybaplaya
# Processing Record 17 of Set 12 | reno
# Processing Record 18 of Set 12 | yendi
# Processing Record 19 of Set 12 | novoagansk
# Processing Record 20 of Set 12 | kajaani
# Processing Record 21 of Set 12 | chagda
# City not found. Skipping
# Processing Record 22 of Set 12 | raudeberg
# Processing Record 23 of Set 12 | kitob
# Processing Record 24 of Set 12 | ocampo
# Processing Record 25 of Set 12 | klaksvik
# Processing Record 26 of Set 12 | shar
# Processing Record 27 of Set 12 | simoes
# Processing Record 28 of Set 12 | santa cruz del sur
# Processing Record 29 of Set 12 | cayambe
# Processing Record 30 of Set 12 | chikoy
# City not found. Skipping
# Processing Record 31 of Set 12 | kampene
# Processing Record 32 of Set 12 | les cayes
# Processing Record 33 of Set 12 | revda
# Processing Record 34 of Set 12 | bom jesus da lapa
# Processing Record 35 of Set 12 | ngunguru
# Processing Record 36 of Set 12 | aras
# Processing Record 37 of Set 12 | shelopugino
# Processing Record 38 of Set 12 | tanete
# Processing Record 39 of Set 12 | nuuk
# Processing Record 40 of Set 12 | karakendzha
# City not found. Skipping
# Processing Record 41 of Set 12 | opuwo
# Processing Record 42 of Set 12 | kununurra
# Processing Record 43 of Set 12 | paita
# Processing Record 44 of Set 12 | malanje
# Processing Record 45 of Set 12 | mabaruma
# Processing Record 46 of Set 12 | laguna
# Processing Record 47 of Set 12 | were ilu
# Processing Record 48 of Set 12 | tocopilla
# Processing Record 49 of Set 12 | garh maharaja
# Processing Record 50 of Set 12 | garissa
# Processing Record 1 of Set 13 | richards bay
# Processing Record 2 of Set 13 | selenginsk
# Processing Record 3 of Set 13 | pacasmayo
# Processing Record 4 of Set 13 | changji
# Processing Record 5 of Set 13 | wanning
# Processing Record 6 of Set 13 | benguela
# Processing Record 7 of Set 13 | warrington
# Processing Record 8 of Set 13 | viransehir
# Processing Record 9 of Set 13 | wangdiphodrang
# City not found. Skipping
# Processing Record 10 of Set 13 | lata
# Processing Record 11 of Set 13 | ouallam
# Processing Record 12 of Set 13 | aklavik
# Processing Record 13 of Set 13 | port augusta
# Processing Record 14 of Set 13 | broome
# Processing Record 15 of Set 13 | tongliao
# Processing Record 16 of Set 13 | jalu
# Processing Record 17 of Set 13 | hornepayne
# Processing Record 18 of Set 13 | toliary
# City not found. Skipping
# Processing Record 19 of Set 13 | pisco
# Processing Record 20 of Set 13 | saint-georges
# Processing Record 21 of Set 13 | sulangan
# Processing Record 22 of Set 13 | seymchan
# Processing Record 23 of Set 13 | lethem
# Processing Record 24 of Set 13 | husavik
# Processing Record 25 of Set 13 | sol-iletsk
# Processing Record 26 of Set 13 | casablanca
# Processing Record 27 of Set 13 | samfya
# Processing Record 28 of Set 13 | pitimbu
# Processing Record 29 of Set 13 | manono
# Processing Record 30 of Set 13 | yumen
# Processing Record 31 of Set 13 | grand river south east
# City not found. Skipping
# Processing Record 32 of Set 13 | itacarambi
# Processing Record 33 of Set 13 | malmo
# Processing Record 34 of Set 13 | shelburne
# Processing Record 35 of Set 13 | swedru
# Processing Record 36 of Set 13 | madera
# Processing Record 37 of Set 13 | darhan
# Processing Record 38 of Set 13 | cooma
# Processing Record 39 of Set 13 | dinsor
# City not found. Skipping
# Processing Record 40 of Set 13 | saint cloud
# Processing Record 41 of Set 13 | kalabo
# Processing Record 42 of Set 13 | camacupa
# Processing Record 43 of Set 13 | masallatah
# Processing Record 44 of Set 13 | recea cristur
# Processing Record 45 of Set 13 | youghal
# Processing Record 46 of Set 13 | ler
# Processing Record 47 of Set 13 | wielun
# Processing Record 48 of Set 13 | rincon
# Processing Record 49 of Set 13 | natividad
# Processing Record 50 of Set 13 | roald
# Processing Record 1 of Set 14 | lumban
# Processing Record 2 of Set 14 | bergerac
# Processing Record 3 of Set 14 | bucerias
# Processing Record 4 of Set 14 | moron
# Processing Record 5 of Set 14 | kutahya
# Processing Record 6 of Set 14 | banda aceh
# Processing Record 7 of Set 14 | alihe
# Processing Record 8 of Set 14 | kayankulam
# Processing Record 9 of Set 14 | saint-joseph
# Processing Record 10 of Set 14 | vagur
# Processing Record 11 of Set 14 | labutta
# City not found. Skipping
# Processing Record 12 of Set 14 | empangeni
# Processing Record 13 of Set 14 | bedesa
# Processing Record 14 of Set 14 | nipawin
# Processing Record 15 of Set 14 | amahai
# Processing Record 16 of Set 14 | karratha
# Processing Record 17 of Set 14 | borgarnes
# Processing Record 18 of Set 14 | wewak
# Processing Record 19 of Set 14 | nelson
# Processing Record 20 of Set 14 | conakry
# Processing Record 21 of Set 14 | luderitz
# Processing Record 22 of Set 14 | issoire
# Processing Record 23 of Set 14 | shelby
# Processing Record 24 of Set 14 | paka
# Processing Record 25 of Set 14 | te anau
# Processing Record 26 of Set 14 | nehe
# Processing Record 27 of Set 14 | tonneins
# Processing Record 28 of Set 14 | poum
# Processing Record 29 of Set 14 | tatarka
# Processing Record 30 of Set 14 | marfino
# Processing Record 31 of Set 14 | aasiaat
# Processing Record 32 of Set 14 | serebryansk
# Processing Record 33 of Set 14 | gao
# Processing Record 34 of Set 14 | mantua
# Processing Record 35 of Set 14 | nador
# Processing Record 36 of Set 14 | santa cruz
# Processing Record 37 of Set 14 | batemans bay
# Processing Record 38 of Set 14 | tasbuget
# City not found. Skipping
# Processing Record 39 of Set 14 | vallenar
# Processing Record 40 of Set 14 | tigil
# Processing Record 41 of Set 14 | acajutla
# Processing Record 42 of Set 14 | darien
# Processing Record 43 of Set 14 | half moon bay
# Processing Record 44 of Set 14 | mama
# Processing Record 45 of Set 14 | menongue
# Processing Record 46 of Set 14 | myitkyina
# Processing Record 47 of Set 14 | kamaishi
# Processing Record 48 of Set 14 | matagami
# Processing Record 49 of Set 14 | tayga
# Processing Record 50 of Set 14 | smirnykh
# Processing Record 1 of Set 15 | sainte-thecle
# Processing Record 2 of Set 15 | gallup
# Processing Record 3 of Set 15 | dzilam gonzalez
# Processing Record 4 of Set 15 | rapid valley
# Processing Record 5 of Set 15 | molepolole
# Processing Record 6 of Set 15 | sabha
# Processing Record 7 of Set 15 | la tuque
# Processing Record 8 of Set 15 | barranca
# Processing Record 9 of Set 15 | capao da canoa
# Processing Record 10 of Set 15 | isabela
# Processing Record 11 of Set 15 | grand gaube
# Processing Record 12 of Set 15 | cardinal
# Processing Record 13 of Set 15 | toftir
# City not found. Skipping
# Processing Record 14 of Set 15 | chor
# Processing Record 15 of Set 15 | luanda
# Processing Record 16 of Set 15 | kathmandu
# Processing Record 17 of Set 15 | bure
# Processing Record 18 of Set 15 | la union
# Processing Record 19 of Set 15 | sao domingos
# Processing Record 20 of Set 15 | tungkang
# City not found. Skipping
# Processing Record 21 of Set 15 | hobyo
# Processing Record 22 of Set 15 | beya
# Processing Record 23 of Set 15 | hirara
# Processing Record 24 of Set 15 | kobyzhcha
# Processing Record 25 of Set 15 | pasighat
# Processing Record 26 of Set 15 | kharp
# Processing Record 27 of Set 15 | treinta y tres
# Processing Record 28 of Set 15 | ertil
# Processing Record 29 of Set 15 | santiago
# Processing Record 30 of Set 15 | magadan
# Processing Record 31 of Set 15 | klobuck
# Processing Record 32 of Set 15 | itoman
# Processing Record 33 of Set 15 | sangar
# Processing Record 34 of Set 15 | auki
# Processing Record 35 of Set 15 | carberry
# Processing Record 36 of Set 15 | davila
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 681

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Ushuaia      AR -54.8000  -68.3000     40.66        75           0
# 1         Mataura      NZ -46.1927  168.8643     41.79        99          99
# 2           Kutum      SD  14.2000   24.6667     75.13        26          77
# 3          Hobart      AU -42.8794  147.3294     55.26        59          40
# 4          Nahrin      AF  36.0649   69.1334     66.52        31           0
# 5         Qaanaaq      GL  77.4840  -69.3632     17.73        73         100
# 6          Lompoc      US  34.6391 -120.4579     62.02        91           0
# 7          Avarua      CK -21.2078 -159.7750     77.05        78          40
# 8  Severo-Kurilsk      RU  50.6789  156.1250     53.46        72          99
# 9   Toda Raisingh      IN  26.0252   75.4849     85.24        43           4
#
#    Wind Speed Current Description
# 0        1.14           clear sky
# 1        6.13          light rain
# 2        8.01       broken clouds
# 3       13.80    scattered clouds
# 4        1.81           clear sky
# 5        5.73     overcast clouds
# 6        9.22           clear sky
# 7       21.85    scattered clouds
# 8       19.08     overcast clouds
# 9       13.40           clear sky

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"

# Recreate the DataFrame by using the new column order
city_data_df = pd.DataFrame(city_data)
# Display sample data
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Ushuaia      AR -54.8000  -68.3000     40.66        75           0
# 1         Mataura      NZ -46.1927  168.8643     41.79        99          99
# 2           Kutum      SD  14.2000   24.6667     75.13        26          77
# 3          Hobart      AU -42.8794  147.3294     55.26        59          40
# 4          Nahrin      AF  36.0649   69.1334     66.52        31           0
# 5         Qaanaaq      GL  77.4840  -69.3632     17.73        73         100
# 6          Lompoc      US  34.6391 -120.4579     62.02        91           0
# 7          Avarua      CK -21.2078 -159.7750     77.05        78          40
# 8  Severo-Kurilsk      RU  50.6789  156.1250     53.46        72          99
# 9   Toda Raisingh      IN  26.0252   75.4849     85.24        43           4
#
#    Wind Speed Current Description
# 0        1.14           clear sky
# 1        6.13          light rain
# 2        8.01       broken clouds
# 3       13.80    scattered clouds
# 4        1.81           clear sky
# 5        5.73     overcast clouds
# 6        9.22           clear sky
# 7       21.85    scattered clouds
# 8       19.08     overcast clouds
# 9       13.40           clear sky

# %%
# Display the data types of each column by using the dtypes Pandas function 
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
